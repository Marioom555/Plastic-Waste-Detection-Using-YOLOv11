# %%
import os
home = os.getcwd()
print(home)
# Out:
# /content

# %%
import os
home = os.getcwd()
print(home)
# Out:
# /content

# %%
! pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.4/910.4 kB 19.7 MB/s eta 0:00:00
# ...

# %%
from IPython import display
display.clear_output()

import ultralytics

ultralytics.checks()
# Out:
# Ultralytics 8.3.64 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.1/107.7 GB disk)
